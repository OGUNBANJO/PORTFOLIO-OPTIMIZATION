# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf

# %%
# Read Data

Stocks = yf.download('CLBAX RLBBX RLBAX FBONX FBAFX BALCX BALFX CLBCX RLBFX ABALX AMBFX CLBEX RLEFX RLBCX RLBGX CLBFX AFMBX RAMHX RLBEX DODGX TRAIX PACLX PRWCX JLGRX OLGAX JLGZX OLGCX JLGPX JLGMX JLGQX SEEGX FDGRX FGCKX FBGRX FBGKX FBALX FBAKX FPURX FPUKX VWNDX VWNEX FOCPX FOCKX PEQLX PEIYX PEYAX PEQNX PEQCX PEQSX PEQRX BHYRX BHYCX BHYSX BHYAX BRHYX BHYIX AHIFX AHTFX CITAX CITCX FTAHX RITBX RITCX CITFX CITEX AHTCX RITAX RITFX RITEX AHITX RITGX RTEHX HIGFX RITHX JGVRX JGTTX JGTUX FCGSX NBPIX NBPTX NBPBX NPNRX NPNEX NPRTX NPNAX NPNCX NRLCX FAGIX FNCMX GLIFX GLFOX PAWAX PRWAX PNAIX FSBDX FGIKX FGRIX',start='2018-03-09', end='2023-03-03', interval='1wk')
Stocks.tail()
# Out:
# [*********************100%***********************]  97 of 97 completed
#             Adj Close                                                     \
#                 ABALX      AFMBX     AHIFX     AHITX     AHTCX     AHTFX
# Date
# 2023-01-30  29.950001  29.940001  9.320524  9.322544  9.328603  9.322544
# 2023-02-06  29.709999  29.700001  9.220000  9.220000  9.220000  9.220000
# 2023-02-13  29.500000  29.500000  9.140000  9.140000  9.140000  9.140000
# 2023-02-20  28.920000  28.920000  9.110000  9.110000  9.110000  9.110000
# 2023-02-27  29.330000  29.330000  9.160000  9.160000  9.160000  9.160000
#
#                                                        ... Volume              \
#                 AMBFX      BALCX      BALFX     BHYAX  ...  RLBCX RLBEX RLBFX
# Date                                                   ...
# 2023-01-30  29.930000  29.709999  29.920000  6.895653  ...    0.0   0.0   0.0
# 2023-02-06  29.690001  29.459999  29.680000  6.800000  ...    0.0   0.0   0.0
# ...

# %%
# Closing price
Stocks = Stocks['Adj Close']
print (Stocks)
# Out:
#                 ABALX      AFMBX     AHIFX     AHITX     AHTCX     AHTFX  \
# Date
# 2018-03-05  22.262455  21.930616  7.691222  7.796594  8.088790  7.803644
# 2018-03-12  22.003212  21.659372  7.668781  7.773844  8.065186  7.780869
# 2018-03-19  21.441517  21.112923  7.623887  7.728340  8.017972  7.735322
# 2018-03-26  21.726101  21.401371  7.623887  7.728340  8.017972  7.735322
# 2018-04-02  21.628525  21.305222  7.671313  7.774871  8.060682  7.781900
# ...               ...        ...       ...       ...       ...       ...
# 2023-01-30  29.950001  29.940001  9.320524  9.322544  9.328603  9.322544
# 2023-02-06  29.709999  29.700001  9.220000  9.220000  9.220000  9.220000
# 2023-02-13  29.500000  29.500000  9.140000  9.140000  9.140000  9.140000
# 2023-02-20  28.920000  28.920000  9.110000  9.110000  9.110000  9.110000
# 2023-02-27  29.330000  29.330000  9.160000  9.160000  9.160000  9.160000
#
#                 AMBFX      BALCX      BALFX     BHYAX  ...      RLBCX  \
# ...

# %%
# Plot the adjusted close price
Stocks.plot(figsize=(10, 7))

# Define the label for the title of the figure
plt.title("Adjusted Close Price of Stocks" % Stocks, fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Adj Close Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

# %%
# Log of percentage change of all stocks in the list
Ret= Stocks.pct_change()
Ret.apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
Ret.head()
# Out:
#                ABALX     AFMBX     AHIFX     AHITX     AHTCX     AHTFX  \
# Date
# 2018-03-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-03-12 -0.011645 -0.012368 -0.002918 -0.002918 -0.002918 -0.002918
# 2018-03-19 -0.025528 -0.025229 -0.005854 -0.005853 -0.005854 -0.005854
# 2018-03-26  0.013273  0.013662  0.000000  0.000000  0.000000  0.000000
# 2018-04-02 -0.004491 -0.004493  0.006221  0.006021  0.005327  0.006021
#
#                AMBFX     BALCX     BALFX     BHYAX  ...     RLBCX     RLBEX  \
# Date                                                ...
# 2018-03-05       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-03-12 -0.012373 -0.009901 -0.011653 -0.003886  ... -0.010977 -0.011666
# 2018-03-19 -0.025083 -0.027577 -0.026094 -0.006502  ... -0.026951 -0.025754
# 2018-03-26  0.013283  0.012972  0.013667  0.000000  ...  0.013343  0.013298
# 2018-04-02 -0.004494 -0.004520 -0.004869  0.005785  ... -0.004515 -0.004499
#
# ...

# %%
Ret.plot(title='stock weekly returns')
# Out:
# <AxesSubplot:title={'center':'stock weekly returns'}, xlabel='Date'>

# %%
Ann_Ret = Ret.mean()*52
print (Ann_Ret)
# Out:
# ABALX    0.064978
# AFMBX    0.068120
# AHIFX    0.039238
# AHITX    0.036497
# AHTCX    0.029090
#            ...
# RTEHX    0.032213
# SEEGX    0.159033
# TRAIX    0.108335
# VWNDX    0.128844
# VWNEX    0.130010
# Length: 97, dtype: float64

# %%
Ann_var = Ret.var()*(52)
Ann_std = Ann_var**0.5
print (Ann_std)
# Out:
# ABALX    0.139602
# AFMBX    0.140559
# AHIFX    0.091888
# AHITX    0.091695
# AHTCX    0.091201
#            ...
# RTEHX    0.091409
# SEEGX    0.282228
# TRAIX    0.184908
# VWNDX    0.285212
# VWNEX    0.286001
# Length: 97, dtype: float64

# %%
rf = 0.005

# %%
Sharpe= (Ann_Ret - rf) / Ann_std

# %%
print("Sharpe ratio", Sharpe)
pd. set_option('display.max_row', 97)
# Out:
# Sharpe ratio ABALX    0.429639
# AFMBX    0.449065
# AHIFX    0.372602
# AHITX    0.343498
# AHTCX    0.264144
#            ...
# RTEHX    0.297707
# SEEGX    0.545774
# TRAIX    0.558843
# VWNDX    0.434217
# VWNEX    0.437095
# Length: 97, dtype: float64

# %%
Sharpe.loc[lambda x : (x>=0.2)]
# Out:
# ABALX    0.429639
# AFMBX    0.449065
# AHIFX    0.372602
# AHITX    0.343498
# AHTCX    0.264144
# AHTFX    0.341538
# AMBFX    0.442739
# BALCX    0.378472
# BALFX    0.425250
# BHYAX    0.251449
# BHYIX    0.282711
# BHYRX    0.225601
# BHYSX    0.257808
# BRHYX    0.293865
# CITAX    0.338727
# CITCX    0.260135
# CITEX    0.320003
# CITFX    0.362406
# CLBAX    0.426390
# CLBCX    0.375595
# CLBEX    0.410378
# CLBFX    0.439403
# DODGX    0.445908
# FAGIX    0.382794
# FBAFX    0.478911
# FBAKX    0.462238
# FBALX    0.458448
# FBGKX    0.529436
# FBGRX    0.526110
# FBONX    0.482462
# FCGSX    0.501224
# FDGRX    0.547443
# FGCKX    0.550472
# FGIKX    0.542521
# FGRIX    0.537995
# FNCMX    0.509950
# FOCKX    0.516478
# FOCPX    0.512646
# FPUKX    0.418830
# FPURX    0.415206
# FSBDX    0.501316
# FTAHX    0.403684
# GLFOX    0.479237
# GLIFX    0.491742
# HIGFX    0.384508
# JGTTX    0.508615
# JGTUX    0.520196
# JGVRX    0.527270
# JLGMX    0.557953
# JLGPX    0.535789
# ...

# %%
sorted_Sharpe=Sharpe.loc[lambda x : (x>=0.2)].sort_values()
print(sorted_Sharpe)
# Out:
# BHYRX    0.225601
# BHYAX    0.251449
# BHYSX    0.257808
# CITCX    0.260135
# RITAX    0.263931
# AHTCX    0.264144
# RITBX    0.265436
# BHYIX    0.282711
# BRHYX    0.293865
# RTEHX    0.297707
# RITCX    0.313663
# CITEX    0.320003
# CITAX    0.338727
# AHTFX    0.341538
# AHITX    0.343498
# RITEX    0.346564
# CITFX    0.362406
# RITHX    0.367614
# AHIFX    0.372602
# CLBCX    0.375595
# RLBBX    0.377287
# RLBAX    0.377896
# RITFX    0.378173
# BALCX    0.378472
# FAGIX    0.382794
# RITGX    0.384508
# HIGFX    0.384508
# RAMHX    0.396877
# FTAHX    0.403684
# RLBCX    0.406536
# CLBEX    0.410378
# FPURX    0.415206
# FPUKX    0.418830
# BALFX    0.425250
# CLBAX    0.426390
# RLBEX    0.427164
# ABALX    0.429639
# VWNDX    0.434217
# VWNEX    0.437095
# CLBFX    0.439403
# RLEFX    0.440613
# AMBFX    0.442739
# DODGX    0.445908
# RLBFX    0.446592
# AFMBX    0.449065
# RLBGX    0.449598
# FBALX    0.458448
# FBAKX    0.462238
# FBAFX    0.478911
# GLFOX    0.479237
# ...

# %%
Ret_Corr = Ret.corr()
print(Ret_Corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 Ret_Corr = Ret.corr()
#       2 print(Ret_Corr)
#
# NameError: name 'Ret' is not defined

# %%
Ret_Covar = Ret.cov()
print(Ret_Covar)

# %%
 
# Import data
df = yf.download('JLGRX JLGMX NPNRX PAWAX NBPBX PRWCX NBPTX FCGSX NPNAX PRWAX TRAIX NPRTX PNAIX NBPIX NRLCX ',start='2018-03-09', end='2023-03-03')
df.tail()
# Out:
# [*********************100%***********************]  15 of 15 completed
#            Adj Close                                                         \
#                FCGSX      JLGMX      JLGRX      NBPBX      NBPIX      NBPTX
# Date
# 2023-02-24     14.85  48.459999  47.849998  42.770000  42.630001  42.740002
# 2023-02-27     14.94  48.720001  48.099998  42.759998  42.619999  42.720001
# 2023-02-28     14.93  48.669998  48.060001  42.529999  42.389999  42.500000
# 2023-03-01     14.85  48.360001  47.750000  42.630001  42.490002  42.599998
# 2023-03-02     14.96  48.720001  48.099998  42.900002  42.759998  42.869999
#
#                                                         ... Volume        \
#                 NPNAX      NPNRX      NPRTX      NRLCX  ...  NBPTX NPNAX
# Date                                                    ...
# 2023-02-24  42.720001  42.650002  42.689999  42.669998  ...      0     0
# 2023-02-27  42.709999  42.639999  42.669998  42.660000  ...      0     0
# ...

# %%
# Closing price
df = df['Adj Close']
df.head()
# Out:
#                FCGSX      JLGMX      JLGRX      NBPBX      NBPIX      NBPTX  \
# Date
# 2018-03-09  7.994203  27.071583  26.862869  24.712799  24.025095  24.505091
# 2018-03-12  8.024143  27.040573  26.831900  24.665291  23.986494  24.465794
# 2018-03-13  7.955707  26.829706  26.627501  24.562353  23.886131  24.363625
# 2018-03-14  7.977094  26.786289  26.577950  24.396069  23.724010  24.198580
# 2018-03-15  7.972816  26.761486  26.559368  24.340643  23.669968  24.143566
#
#                 NPNAX      NPNRX      NPRTX  NRLCX      PAWAX      PNAIX  \
# Date
# 2018-03-09  24.469547  24.818836  24.250181    NaN  29.989046  30.467436
# 2018-03-12  24.430307  24.779116  24.211254    NaN  29.983294  30.461718
# 2018-03-13  24.328287  24.667887  24.102264    NaN  29.735783  30.204245
# 2018-03-14  24.163485  24.501055  23.946566    NaN  29.672464  30.147028
# 2018-03-15  24.108545  24.445442  23.892071    NaN  29.672464  30.141306
#
#                 PRWAX      PRWCX      TRAIX
# Date
# ...

# %%
# Log of percentage change and create Covariance matrix
cov_matrix = df.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
#           FCGSX     JLGMX     JLGRX     NBPBX     NBPIX     NBPTX     NPNAX  \
# FCGSX  0.000293  0.000266  0.000267  0.000157  0.000157  0.000157  0.000157
# JLGMX  0.000266  0.000257  0.000257  0.000155  0.000155  0.000155  0.000155
# JLGRX  0.000267  0.000257  0.000258  0.000155  0.000155  0.000155  0.000155
# NBPBX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NBPIX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NBPTX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NPNAX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NPNRX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NPRTX  0.000157  0.000155  0.000155  0.000192  0.000192  0.000192  0.000192
# NRLCX  0.000173  0.000170  0.000170  0.000221  0.000220  0.000221  0.000220
# PAWAX  0.000233  0.000220  0.000221  0.000153  0.000152  0.000153  0.000152
# ...

# %%
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
#           FCGSX     JLGMX     JLGRX     NBPBX     NBPIX     NBPTX     NPNAX  \
# FCGSX  1.000000  0.969947  0.970737  0.662448  0.662231  0.662132  0.662298
# JLGMX  0.969947  1.000000  0.998758  0.698856  0.698545  0.698539  0.698459
# JLGRX  0.970737  0.998758  1.000000  0.697767  0.697456  0.697495  0.697416
# NBPBX  0.662448  0.698856  0.697767  1.000000  0.999927  0.999922  0.999908
# NBPIX  0.662231  0.698545  0.697456  0.999927  1.000000  0.999924  0.999909
# NBPTX  0.662132  0.698539  0.697495  0.999922  0.999924  1.000000  0.999910
# NPNAX  0.662298  0.698459  0.697416  0.999908  0.999909  0.999910  1.000000
# NPNRX  0.662355  0.698702  0.697615  0.999931  0.999920  0.999923  0.999913
# NPRTX  0.662319  0.698770  0.697676  0.999925  0.999920  0.999928  0.999913
# NRLCX  0.666168  0.708559  0.707391  0.999939  0.999940  0.999940  0.999920
# PAWAX  0.955664  0.965731  0.966794  0.774149  0.773993  0.774017  0.773978
# ...

# %%
w = {'FCGSX':0.067, 'JLGMX':0.067, 'JLGRX':0.067, 'NBPBX':0.067, 'NBPIX':0.067, 'NBPTX':0.067, 'NPNAX':0.067, 'NPNRX':0.067, 'NPRTX':0.067, 'NRLCX':0.067, 'PAWAX':0.067, 'PNAIX':0.067, 'PRWAX':0.067, 'PRWCX':0.067, 'TRAIX':0.067}
port_var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 0.00016920670265208995
# 0.008798748537908678

# %%
Ann_port_std
# Out:
# 0.09380164464394362

# %%
# Yearly returns for individual companies
ind_er = df.resample('Y').last().pct_change().mean()
ind_er
# Out:
# FCGSX    0.222771
# JLGMX    0.185960
# JLGRX    0.184894
# NBPBX    0.125979
# NBPIX    0.130776
# NBPTX    0.127419
# NPNAX    0.127705
# NPNRX    0.124557
# NPRTX    0.129248
# NRLCX    0.103832
# PAWAX    0.164257
# PNAIX    0.169092
# PRWAX    0.166992
# PRWCX    0.104660
# TRAIX    0.105694
# dtype: float64

# %%
# Portfolio returns
w = [0.67, 0.67, 0.67, 0.67,0.67,0.67,0.67,0.67,0.67,0.67,0.67,0.67,0.67,0.67,0.67]
port_er = (w*ind_er).sum()
port_er
# Out:
# 1.4564691343257241

# %%
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(52))
ann_sd
# Out:
# FCGSX    0.123401
# JLGMX    0.115658
# JLGRX    0.115888
# NBPBX    0.099921
# NBPIX    0.099896
# NBPTX    0.099949
# NPNAX    0.099851
# NPNRX    0.099875
# NPRTX    0.099860
# NRLCX    0.107064
# PAWAX    0.102558
# PNAIX    0.102572
# PRWAX    0.102583
# PRWCX    0.067175
# TRAIX    0.067158
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#         Returns  Volatility
# FCGSX  0.222771    0.123401
# JLGMX  0.185960    0.115658
# JLGRX  0.184894    0.115888
# NBPBX  0.125979    0.099921
# NBPIX  0.130776    0.099896
# NBPTX  0.127419    0.099949
# NPNAX  0.127705    0.099851
# NPNRX  0.124557    0.099875
# NPRTX  0.129248    0.099860
# NRLCX  0.103832    0.107064
# PAWAX  0.164257    0.102558
# PNAIX  0.169092    0.102572
# PRWAX  0.166992    0.102583
# PRWCX  0.104660    0.067175
# TRAIX  0.105694    0.067158

# %%
import matplotlib.pyplot as plt
x = ann_sd # RISK
y = ind_er # Return
plt.scatter(x, y)
plt.show()

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights
num_assets = len(df.columns)
num_portfolios = 10000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
 # weights 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 15 portfolios created
# Out:
#     Returns  Volatility  FCGSX weight  JLGMX weight  JLGRX weight  \
# 0  0.146890    0.094036      0.106464      0.066114      0.106270
# 1  0.140398    0.091914      0.072668      0.003002      0.102705
# 2  0.140096    0.094038      0.023383      0.125228      0.063004
# 3  0.141459    0.091982      0.048168      0.042527      0.067485
# 4  0.145059    0.090882      0.110565      0.070493      0.052916
#
#    NBPBX weight  NBPIX weight  NBPTX weight  NPNAX weight  NPNRX weight  \
# 0      0.008319      0.100609      0.075070      0.060286      0.087180
# 1      0.085163      0.067202      0.125886      0.082010      0.008855
# 2      0.079827      0.123001      0.039175      0.130082      0.068157
# 3      0.065834      0.098078      0.068048      0.051793      0.013975
# 4      0.031838      0.058249      0.109189      0.109562      0.046371
#
#    NPRTX weight  NRLCX weight  PAWAX weight  PNAIX weight  PRWAX weight  \
# ...

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified. 
min_vol_port
# Out:
# Returns         0.132286
# Volatility      0.086033
# FCGSX weight    0.011863
# JLGMX weight    0.055160
# JLGRX weight    0.002267
# NBPBX weight    0.004487
# NBPIX weight    0.119146
# NBPTX weight    0.082377
# NPNAX weight    0.141350
# NPNRX weight    0.052293
# NPRTX weight    0.023598
# NRLCX weight    0.009916
# PAWAX weight    0.119067
# PNAIX weight    0.013488
# PRWAX weight    0.056128
# PRWCX weight    0.171008
# TRAIX weight    0.137852
# Name: 6221, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns         0.172519
# Volatility      0.103218
# FCGSX weight    0.173777
# JLGMX weight    0.193487
# JLGRX weight    0.173690
# NBPBX weight    0.023445
# NBPIX weight    0.001462
# NBPTX weight    0.003799
# NPNAX weight    0.094833
# NPNRX weight    0.021423
# NPRTX weight    0.045884
# NRLCX weight    0.001093
# PAWAX weight    0.202233
# PNAIX weight    0.005542
# PRWAX weight    0.014261
# PRWCX weight    0.039868
# TRAIX weight    0.005201
# Name: 3909, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
